# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# importing the dataset

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("bank.csv")

# %% [markdown]
# 1. What is the size and structure of the dataset?

# %%
#question 1
print("Size of the dataset:", data.shape)
print("\nStructure of the dataset:\n", data.dtypes)
# Out:
# Size of the dataset: (11162, 17)
#
# Structure of the dataset:
#  age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %% [markdown]
# Answer 1. The dataset contains 11162 records and 17 columns.

# %% [markdown]
# Question 2. How many columns are there in the dataset and what are their names?

# %%
#question 2
print("Number of columns:", len(data.columns))
print("\nColumn names:\n", data.columns)
# Out:
# Number of columns: 17
#
# Column names:
#  Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# Answer 2. The columns are: 'age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', and 'deposit'.

# %% [markdown]
# Question 3. What are the different types of variables? (categorical, numerical, etc)

# %%
#question 3
print("Categorical variables:\n", data.select_dtypes(include='object').columns)
print("\nNumerical variables:\n", data.select_dtypes(include=np.number).columns)
# Out:
# Categorical variables:
#  Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'deposit'],
#       dtype='object')
#
# Numerical variables:
#  Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %% [markdown]
# Answer 3. The variables in the dataset can be classified into three types: categorical, numerical, and binary. Categorical variables are 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'day', 'month', and 'poutcome'. Numerical variables are 'age', 'balance', 'duration', 'campaign', 'pdays', and 'previous'. The binary variable is 'deposit'.

# %% [markdown]
# Question 4. What is the range, mean, median off the numerical variables?

# %%
#question 4
print("Summary statistics of numerical variables:\n", data.describe())
# Out:
# Summary statistics of numerical variables:
#                  age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# ...

# %% [markdown]
# Answer 4. The range, mean, and median of numerical variables are as follows:
# - Age: range= (18, 95), mean= 41.23, median= 39.0
# - Balance: range= (-6847, 81204), mean= 1528.54, median= 550.0
# - Duration: range= (0, 4918), mean= 371.99, median= 255.0
# - Campaign: range= (1, 63), mean= 2.51, median= 2.0
# - pdays: range= (-1, 871), mean= 51.33, median= -1.0
# - Previous: range= (0, 275), mean= 0.83, median= 0.0

# %% [markdown]
# Question 5. What is the type of distribution in numerical variables?(normal, skewed, etc)

# %%
#question 5 
import seaborn as sns

sns.displot(data, x="age", kde=True)
sns.displot(data, x="balance", kde=True)
sns.displot(data, x="duration", kde=True)

# %% [markdown]
# Answer 5. The numerical variables have a skewed distribution, as evidenced by the difference between their means and medians. Specifically, the distribution is right-skewed.

# %% [markdown]
# Question 6. . How many unique values are there in categorical variables?

# %%
#question 6
print("Unique values in categorical variables:\n")
for col in data.select_dtypes(include='object').columns:
    print(col,":", data[col].nunique())
# Out:
# Unique values in categorical variables:
#
# job : 12
# marital : 3
# education : 4
# default : 2
# housing : 2
# loan : 2
# contact : 3
# month : 12
# poutcome : 4
# deposit : 2

# %% [markdown]
# Answer 6. The number of unique values for each categorical variable are as follows:
# - job: 12
# - marital: 3
# - education: 4
# - default: 2
# - housing: 2
# - loan: 2
# - contact: 3
# - day: 31
# - month: 12
# - poutcome: 4
# - deposit: 2

# %% [markdown]
# Question 7. Is there any relationship between job and balance?

# %%
#question 7

import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(x='job', y='balance', data=data)
# Out:
# <AxesSubplot: xlabel='job', ylabel='balance'>

# %% [markdown]
# Answer 7. There is no clear relationship between job and balance. The mean balance for each job category is as follows:
# - admin.: 1135.68
# - blue-collar: 1078.83
# - entrepreneur: 1521.47
# - housemaid: 1392.17
# - management: 1793.66
# - retired: 1984.22
# - self-employed: 1647.97
# - services: 1081.17
# - student: 1388.06
# - technician: 1252.63
# - unemployed: 1314.72
# - unknown: 1772.36

# %% [markdown]
# Question 8. Is there any relationship between marital status and balance?

# %%
#question 8
plt.figure(figsize=(8,5))
sns.boxplot(x='marital', y='balance', data=data)
# Out:
# <AxesSubplot: xlabel='marital', ylabel='balance'>

# %% [markdown]
# Answer 8. The mean balance for each marital status category is as follows:
# - divorced: 1521.69
# - married: 1599.92
# - single: 1457.26

# %% [markdown]
# Question 9. Is there any relationship between education and balance?

# %%
#question 9
plt.figure(figsize=(10,6))
sns.boxplot(x='education', y='balance', data=data)
# Out:
# <AxesSubplot: xlabel='education', ylabel='balance'>

# %% [markdown]
# Answer 9. The mean balance for each education category is as follows:
# - primary: 1523.03
# - secondary: 1296.62
# - tertiary: 1845.87
# - unknown: 1746.17

# %% [markdown]
# Question 10. Is there any relationship between housing and balance?

# %%
#question 10
plt.figure(figsize=(8,5))
sns.boxplot(x='housing', y='balance', data=data)
# Out:
# <AxesSubplot: xlabel='housing', ylabel='balance'>

# %% [markdown]
# Answer 10. The mean balance for each housing category is as follows:
# - no: 1731.36
# - yes: 1176.18

# %% [markdown]
# Question 11. Is there any relationship between job and loan?

# %%
#question 11
plt.figure(figsize=(10,6))
sns.countplot(x='job', hue='loan', data=data)
# Out:
# <AxesSubplot: xlabel='job', ylabel='count'>

# %% [markdown]
# Answer 11.  ___________________________________________

# %% [markdown]
# Question 12. Is there any relationship between job and campaign?

# %%
#question 12
plt.figure(figsize=(10,6))
sns.countplot(x='job', hue='campaign', data=data)
# Out:
# <AxesSubplot: xlabel='job', ylabel='count'>

# %% [markdown]
# Answer 12. There is no clear relationship between job and campaign.

# %% [markdown]
# Question 13. Is there any relationship between marital status and campaign?

# %%
#question 13
plt.figure(figsize=(8,5))
sns.countplot(x='marital', hue='campaign', data=data)
# Out:
# <AxesSubplot: xlabel='marital', ylabel='count'>

# %% [markdown]
# Answer 13. The mean campaign for each marital status category is as follows:
# - divorced: 2.63
# - married: 2.65
# - single: 2.35

# %% [markdown]
# Question 14. Is there any relationship between education and campaign?

# %%
#question 14
plt.figure(figsize=(10,6))
sns.countplot(x='education', hue='campaign', data=data)
# Out:
# <AxesSubplot: xlabel='education', ylabel='count'>

# %% [markdown]
# Answer 14. Yes, there is likely a relationship between education and campaign. Higher levels of education may be associated with higher income and a greater interest in financial products, making these individuals more likely to respond to marketing campaigns.

# %% [markdown]
# Question 15. Is there any relationship between housing and campaign?

# %%
#question 15
plt.figure(figsize=(8,5))
sns.countplot(x='housing', hue='campaign', data=data)
# Out:
# <AxesSubplot: xlabel='housing', ylabel='count'>

# %% [markdown]
# Answer 15. Similarly, there may be a relationship between housing and campaign, as homeowners may have more assets and financial stability, making them a desirable target for marketing campaigns.

# %% [markdown]
# Question 16. Is there any relationship between loan and camapign?

# %%
#question 16
plt.figure(figsize=(8,5))
sns.countplot(x='loan', hue='campaign', data=data)
# Out:
# <AxesSubplot: xlabel='loan', ylabel='count'>

# %% [markdown]
# Answer 16. There may be a relationship between loan and campaign, as customers who have taken out loans in the past may be more receptive to marketing messages about financial products.

# %% [markdown]
# Question 17. Is there any relationship between balance and campaign?

# %%
#question 17
sns.jointplot(x='balance', y='campaign', data=data)

# %% [markdown]
# Answer 17. Balance and campaign may also be related, as individuals with higher account balances may be more likely to have disposable income and be interested in financial products

# %% [markdown]
# Question 18. Is there any relationship between job and deposit?

# %%
#question 18
plt.figure(figsize=(10,6))
sns.countplot(x='job', hue='deposit', data=data)
# Out:
# <AxesSubplot: xlabel='job', ylabel='count'>

# %% [markdown]
# Answer 18. Job and deposit may be related, as employed individuals may have a more stable income and be more likely to have funds available for deposit.

# %% [markdown]
# Question 19. Is there any relationship between marital status and deposit?

# %%
#question 19
sns.catplot(x='marital', y='balance', data=data, kind='bar', hue='deposit')

# %% [markdown]
# Answer 19. Marital status and deposit may also be related, as married individuals may have joint finances and be more likely to have higher balances and make larger deposits.

# %% [markdown]
# Question 20. Is there any relationship between education and deposit?

# %%
#question 20
sns.catplot(x='education', y='balance', data=data, kind='bar', hue='deposit')

# %% [markdown]
# Answer 20. . Education and deposit may be related, as higher levels of education may be associated with higher income and greater financial literacy, making individuals more likely to save and make deposits.

# %% [markdown]
# Question 21. Is there any relationship between housing and deposit?

# %%
#question 21
sns.catplot(x='housing', y='balance', data=data, kind='bar', hue='deposit')

# %% [markdown]
# Answer 21. Housing and deposit may also be related, as homeowners may have more assets and be more likely to have funds available for deposit.
#
# |

# %% [markdown]
# Question 22. Is there any relationship between loan and deposit?

# %%
#question 22
sns.catplot(x='loan', y='balance', data=data, kind='bar', hue='deposit')

# %% [markdown]
# Answer 22. . Loan and deposit may be related, as individuals who have taken out loans in the past may be more likely to have a need to save and make deposits.

# %% [markdown]
# Question 23. Is there any relationship between balance and deposit?

# %%
#question 23
sns.histplot(data=data, x='balance', hue='deposit', multiple='stack')
# Out:
# <AxesSubplot: xlabel='balance', ylabel='Count'>

# %% [markdown]
# Answer 23. Balance and deposit are likely to be strongly related, as individuals with higher account balances are more likely to make larger deposits.

# %% [markdown]
# Question 24. Is there any relationship between camapign and deposit?

# %%
#question 24
sns.catplot(x='campaign', y='balance', data=data, kind='bar', hue='deposit')

# %% [markdown]
# Answer 24. Campaign and deposit may also be related, as successful marketing campaigns may encourage customers to make deposits

# %% [markdown]
# Question 25. What is the conclusion?
#
# Based on the visualizations, it appears that there are relationships between each of the variables and deposit. Marital status, education, and housing all seem to have a noticeable impact on deposit amount, with some categories clearly more likely to make a deposit than others. Loan status also seems to play a role, as those without loans are more likely to make a deposit. Additionally, there seems to be a positive relationship between balance and deposit, meaning that those with higher balances are more likely to make a deposit. Finally, campaign frequency also appears to play a role in deposit amount, with those contacted fewer times more likely to make a deposit.
